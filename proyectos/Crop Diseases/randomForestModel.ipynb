# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import joblib

# %%
df = pd.read_csv("cropData.csv")

# %%
df.head()
# Out:
#    Temperature  Humidity  Rainfall  Soil_pH    N   P   K    Crop  \
# 0         21.3      61.5     134.1     5.89   64  59  27  Potato
# 1         22.2      67.5     149.2     6.12   83  22  44  Potato
# 2         22.6      53.0     127.0     6.59  101  39  43   Wheat
# 3         34.1      48.8     271.5     6.49   94  36  36    Rice
# 4         37.6      40.0     237.4     6.57   64  50  36  Cotton
#
#             Disease
# 0      Early Blight
# 1       Late Blight
# 2    Powdery Mildew
# 3        Leaf Blast
# 4  Bacterial Blight

# %%
df.isnull().sum()
# Out:
# Temperature    0
# Humidity       0
# Rainfall       0
# Soil_pH        0
# N              0
# P              0
# K              0
# Crop           0
# Disease        0
# dtype: int64

# %%
df.describe()
# Out:
#        Temperature     Humidity     Rainfall      Soil_pH            N  \
# count  3660.000000  3660.000000  3660.000000  3660.000000  3660.000000
# mean     27.421776    70.252459   180.633251     6.467085    89.844536
# std       5.308921    12.850265    48.458867     0.441650    15.086890
# min      13.600000    36.600000    10.700000     5.080000    50.000000
# 25%      23.000000    61.000000   150.200000     6.150000    80.000000
# 50%      27.300000    71.800000   173.600000     6.440000    91.000000
# 75%      31.600000    80.100000   205.400000     6.740000   100.000000
# max      40.900000   104.200000   318.200000     8.280000   131.000000
#
#                  P            K
# count  3660.000000  3660.000000
# mean     42.448907    36.084426
# std       9.500528     8.974150
# min      20.000000    15.000000
# 25%      36.000000    30.000000
# 50%      43.000000    36.000000
# 75%      49.000000    42.000000
# max      67.000000    63.000000

# %%
la_crop = LabelEncoder()
la_disease = LabelEncoder()

# %%
df['cropEncoded'] = la_crop.fit_transform(df['Crop'])
df['diseaseEncoded'] = la_disease.fit_transform(df['Disease'])

# %%
x = df[['Temperature', 'Humidity', 'Rainfall', 'Soil_pH', 'N', 'P', 'K', 'cropEncoded']]
y = df['diseaseEncoded']

# %%
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(xTrain, yTrain)
# Out:
# RandomForestClassifier(random_state=42)

# %%
yPred = model.predict(xTest)

# %%
accuracy_score(yTest, yPred)
# Out:
# 0.9030054644808743

# %%
classification_report(yTest, yPred, target_names = la_disease.classes_)
# Out:
# D:\Codes\Optimus\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\Codes\Optimus\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\Codes\Optimus\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# '                       precision    recall  f1-score   support\n\n          Anthracnose       0.93      0.93      0.93        27\n           Apple Scab       0.87      1.00      0.93        26\n     Bacterial Blight       1.00      0.91      0.95        32\nBacterial Leaf Blight       0.96      0.84      0.90        32\n       Bacterial Spot       0.84      0.90      0.87        30\n          Black Scurf       0.00      0.00      0.00         3\n           Brown Spot       0.93      1.00      0.96        26\n     Cedar Apple Rust       1.00      0.90      0.95        31\n          Common Rust       0.95      0.88      0.91        24\n          Common Scab       0.93      1.00      0.96        25\n         Downy Mildew       0.00      0.00      0.00         2\n         Early Blight       0.91      0.94      0.93        72\n          Fire Blight       0.97      1.00      0.98        28\n       Gray Leaf Spot       0.95      1.00      0.98        20\n          Karnal Bunt       0.00      0.00      0.00         4\n          Late Blight       0.88      0.92      0.90        61\n           Leaf Blast       0.88      0.97      0.92        31\n            Leaf Curl       1.00      0.50      0.67         2\n            Leaf Rust       0.92      1.00      0.96        36\n            Leaf Spot       0.81      0.86      0.84        51\n       Powdery Mildew       0.92      0.88      0.90        66\n             Root Rot       0.00      0.00      0.00         4\n                 Rust       0.50      0.17      0.25         6\n   Septoria Leaf Spot       0.96      0.84      0.90        32\n        Sheath Blight       0.00      0.00      0.00         2\n Turcicum Leaf Blight       0.91      0.97      0.94        30\n    Verticillium Wilt       0.83      1.00      0.91        29\n\n             accuracy                           0.90       732\n            macro avg       0.74      0.72      0.72       732\n         weighted avg       0.89      0.90      0.89       732\n'

# %%
featImportances = model.feature_importances_
features = x.columns

# %%
plt.barh(features, featImportances)
plt.xlabel("Feature Importance")
plt.title("Random Forest Feature Importance")
plt.show()

# %%
joblib.dump(model, "disease_predictor.pkl")
joblib.dump(la_crop, "crop_encoder.pkl")
joblib.dump(la_disease, "disease_encoder.pkl")
# Out:
# ['disease_encoder.pkl']
